# %% [markdown]
# ## LAB - S03-L007-LAB Sortowanie data frame
#
# 1. Zaimportuj moduł pandas oraz numpy i nadaj im standardowe aliasy. Do zmiennej fuel wczytaj zawartośćpliku fuel.csv. Podczas wczytywania skorzystaj z dodatkowego argumentu low_memory=False, pobierztylko następujące kolumny: 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'.Indeksem ma być kolumna Vehicle ID. Wyświetl nagłówek tak utworzonego Data Frame
# 2. Wykonaj poniższe polecenia, żeby wprowadzić nowe wartości NaN do pierwszych wierszy zmiennej fuel
#    ##### fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN
# 3. Wyświetl nagłówek fuel żeby upewnić się, że wiersze rzeczywiście zawierają wartości NaN
# 4. Posortuj fuel rosnąco wg 'Make','Model'. Wyświetl początkowe 5 wierszy
# 5. Posortuj fuel malejąco wg 'Combined MPG (FT1)', wyświetl początkowych 5 wierszy
# 6. Posortuj fuel wg 'Make','Combined MPG (FT1)'. Piewsza kolumna ma być sortowana rosnąca, ale druga -malejąco. Wyświetl nagłówek
# 7. Posortuj fuel rosnąco wg kolumny 'Combined MPG (FT1)' tak, aby wartość NaN była na początku.Wyświetl nagłówek
# 8. Ponownie wykonaj poprzedni punkt, ale tym razem sortowanie ma się odbyć w oryginalnym obiekcie.Wyświetl nagłówek
# 9. Posortuj fuel rosnąco wg indeksu. Wyświetl nagłówek.

# %%
import pandas as pd
import numpy as np

# %%
fuel = pd.read_csv('../zasoby/fuel.csv', low_memory=False, usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')

# %%
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550        Regular                17.0

# %%
fuel.sort_values(by=['Make','Model']).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
# 1032        1985  AM General  Post Office DJ5 2WD
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0

# %%
fuel.sort_values(by='Combined MPG (FT1)', ascending=False).head()
# Out:
#             Year        Make           Model             Class    Fuel Type  \
# Vehicle ID
# 31673       2012  Mitsubishi          i-MiEV   Subcompact Cars  Electricity
# 32278       2012        Ford  Focus Electric      Compact Cars  Electricity
# 32276       2011         BMW        Active E   Subcompact Cars  Electricity
# 30979       2011      Nissan            Leaf      Midsize Cars  Electricity
# 30978       2008        MINI           MiniE  Minicompact Cars  Electricity
#
#             Combined MPG (FT1)
# Vehicle ID
# 31673                    112.0
# 32278                    105.0
# 32276                    102.0
# 30979                     99.0
# 30978                     98.0

# %%
fuel.sort_values(by=['Make','Combined MPG (FT1)'],ascending=[True, False]).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel.sort_values(by='Combined MPG (FT1)', na_position='first').head()
# Out:
#             Year         Make               Model        Class Fuel Type  \
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0

# %%
fuel.sort_values(by='Combined MPG (FT1)', na_position='first', inplace=True)

# %%
fuel.head()
# Out:
#             Year         Make               Model        Class Fuel Type  \
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0

# %%
fuel.sort_index().head()
# Out:
#             Year        Make               Model        Class Fuel Type  \
# Vehicle ID
# 1           1985  Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 2           1985     Bertone                X1/9  Two Seaters   Regular
# 3           1985   Chevrolet            Corvette  Two Seaters   Regular
# 4           1985   Chevrolet            Corvette  Two Seaters   Regular
# 5           1985      Nissan               300ZX  Two Seaters   Regular
#
#             Combined MPG (FT1)
# Vehicle ID
# 1                         21.0
# 2                         22.0
# 3                         17.0
# 4                         17.0
# 5                         16.0
