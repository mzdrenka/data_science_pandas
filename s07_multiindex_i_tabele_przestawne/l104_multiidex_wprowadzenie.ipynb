# %% [markdown]
# ## LAB - S05-L001-Multiindex - intro
#
# 1. Zaimportuj moduł pandas i numpy, nadaj im standardowe aliasy. Do zmiennej air wczytaj zawartość pliku Air_Traffic_Passenger_Statistics.csv. Pobierz wszystkie kolumny. Wyświetl nagłówek obiektu data frame.
# 2. Zmień indeks na "Operating Airline","Activity Period". Wyświetl 10 pierwszych wierszy
# 3. Zresetuj indeks. Wyświetl nagłówek
# 4. Zmień indeks na "Activity Period","Operating Airline". Wyświetl 10 pierwszych wierszy
# 5. Posortuj dane tak, aby pierwsza kolumna indeksu była uporządkowana w kolejności malejącej, a druga w kolejności rosnącej. Wyświetl nagłówek z 10 wierszami
# 6. Zresetuj indeks. Wyświetl nagłówek
# 7. Zmień indeks na "Activity Period","Operating Airline","Activity Type Code". Wyświetl 10 pierwszych wierszy

# %%
import pandas as pd
import numpy as np

# %%
air = pd.read_csv('../zasoby/Air_Traffic_Passenger_Statistics.csv')
air.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
air.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 18398 entries, ('ATA Airlines', 200507) to ('WOW Air', 201803)
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Operating Airline IATA Code  18335 non-null  object
#  1   Published Airline            18398 non-null  object
#  2   Published Airline IATA Code  18335 non-null  object
#  3   GEO Summary                  18398 non-null  object
#  4   GEO Region                   18398 non-null  object
#  5   Activity Type Code           18398 non-null  object
#  6   Price Category Code          18398 non-null  object
#  7   Terminal                     18398 non-null  object
#  8   Boarding Area                18398 non-null  object
#  9   Passenger Count              18398 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 10.3 MB

# %%
air.set_index(keys=["Operating Airline","Activity Period"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7k/5fhj4y514c5652gjp225_dph0000gn/T/ipykernel_15846/673206670.py in ?()
# ----> 1 air.set_index(keys=["Operating Airline","Activity Period"], inplace=True)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['Operating Airline', 'Activity Period'] are in the columns"

# %%
air.reset_index(inplace=True)
air.set_index(keys=["Activity Period","Operating Airline"], inplace=True)

# %%
air.head()
# Out:
#                                   Operating Airline IATA Code  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ
#                   200507                                   TZ
#                   200507                                   TZ
# Air Canada        200507                                   AC
#                   200507                                   AC
#
#                                   Published Airline  \
# Operating Airline Activity Period
# ATA Airlines      200507               ATA Airlines
#                   200507               ATA Airlines
#                   200507               ATA Airlines
# Air Canada        200507                 Air Canada
#                   200507                 Air Canada
#
#                                   Published Airline IATA Code    GEO Summary  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ       Domestic
# ...

# %%
air.sort_index(ascending=[False, True], inplace=True)
air.head()
# Out:
#                                                          Operating Airline IATA Code  \
# Activity Period Operating Airline
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet                          4O
#                 ABC Aerolineas S.A. de C.V. dba Interjet                          4O
#                 Aer Lingus                                                        EI
#                 Aer Lingus                                                        EI
#                 Aeromexico                                                        AM
#
#                                                                                  Published Airline  \
# Activity Period Operating Airline
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet  ABC Aerolineas S.A. de C.V. dba Interjet
#                 ABC Aerolineas S.A. de C.V. dba Interjet  ABC Aerolineas S.A. de C.V. dba Interjet
# ...

# %%
air.reset_index(inplace=True)

# %%
air.set_index(keys=["Activity Period","Operating Airline","Activity Type Code"], inplace=True)
air.head()
# Out:
#                                                                             Operating Airline IATA Code  \
# Activity Period Operating Airline                        Activity Type Code
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet Deplaned                                    4O
#                                                          Enplaned                                    4O
#                 Aer Lingus                               Deplaned                                    EI
#                                                          Enplaned                                    EI
#                 Aeromexico                               Deplaned                                    AM
#
#                                                                                                     Published Airline  \
# Activity Period Operating Airline                        Activity Type Code
# ...
